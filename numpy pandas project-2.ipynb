# %% [markdown]
# #Calling Numpy and pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Import Dataset

# %%
dataset=pd.read_csv('/content/chipotle(1).tsv',sep='\t')

# %% [markdown]
# #Shape of Dataset

# %%
dataset.shape
# Out:
# (4622, 5)

# %% [markdown]
# #First values

# %%
dataset.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %% [markdown]
# #finding Null Values

# %%
dataset.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %% [markdown]
# #Replace of $

# %%
dataset['item_price']=dataset['item_price'].str.replace("$","")
dataset.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# 3                                                NaN      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98

# %% [markdown]
# Replace nan Value with not applicabe

# %% [markdown]
# #statistics of Data set

# %%
dataset.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %% [markdown]
# #data types

# %%
dataset.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %% [markdown]
# #change of data type for item_price

# %%
dataset['item_price']=dataset['item_price'].astype(float)

# %% [markdown]
# #Finding Duplicate values

# %%
dataset.duplicated().sum()
# Out:
# 59

# %% [markdown]
# #Droping Duplicate Values

# %%
df=dataset.drop_duplicates(inplace=True)

# %% [markdown]
# #shape

# %%
dataset.shape
# Out:
# (4563, 5)

# %% [markdown]
# #Quantity of Each Item

# %%
#Quantity of each item
x=dataset.groupby('item_name').sum()
x=x.sort_values(['quantity'],ascending=False)
x.head(20)
# Out:
#                               order_id  quantity  \
# item_name
# Chicken Bowl                    704980       752
# Chicken Burrito                 490718       584
# Chips and Guacamole             443669       501
# Steak Burrito                   327829       383
# Canned Soft Drink               296817       340
# Chips                           204975       227
# Steak Bowl                      192568       220
# Bottled Water                   166833       204
# Chips and Fresh Tomato Salsa    100419       130
# Canned Soda                      74804       124
# Chicken Salad Bowl              117104       123
# Chicken Soft Tacos               94665       116
# Side of Chips                    84769       110
# Veggie Burrito                   80962        97
# Barbacoa Burrito                 72891        90
# Veggie Bowl                      72270        87
# Carnitas Bowl                    62742        71
# Barbacoa Bowl                    53396        65
# ...

# %% [markdown]
# #2.	What was the most ordered item in the choice_description column

# %%
d=dataset['choice_description'].value_counts()
d.head(1)
# Out:
# choice_description
# [Diet Coke]    133
# Name: count, dtype: int64

# %% [markdown]
# #3.	How many items were ordered in total

# %%
dataset.quantity.sum()
# Out:
# 4913

# %% [markdown]
# #Add nwe Column Revenue
# #How much was the revenue for the period in the dataset

# %%
dataset['Revenue']=dataset.quantity*dataset.item_price
dataset.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  Revenue
# 0                                                NaN        2.39     2.39
# 1                                       [Clementine]        3.39     3.39
# 2                                            [Apple]        3.39     3.39
# 3                                                NaN        2.39     2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98    33.96

# %%
dataset['Revenue'].sum()
# Out:
# 38914.11

# %% [markdown]
# #5.	How many orders were made in the period

# %%
order=dataset.order_id.value_counts().count()
order
# Out:
# 1834

# %% [markdown]
# #6.	What is the average revenue amount per order

# %%
d=dataset.groupby(by=['order_id']).sum()
d['Revenue'].mean()
# Out:
# 21.218162486368595

# %% [markdown]
# #7.	How many different items are sold

# %%
dataset.item_name.value_counts().count()
# Out:
# 50
